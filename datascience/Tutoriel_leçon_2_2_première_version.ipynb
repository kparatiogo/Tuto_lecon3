# %% [markdown]
# ### 1) Définissons un whyqd Schéma pour décrire et spécifier les critères de validation de notre jeu de données.

# %%
import whyqd as _w
schema = _w.Schema()

# %%
details = {
        "name": "Carbon_dioxide_emissions_and_stocks",
        "title": "Carbon dioxide emissions and stocks in the world",
        "description": """
        Le dioxyde de carbone, aussi appelé gaz carbonique ou anhydride carbonique. À partir d'une certaine
        concentration dans l'air, ce gaz s'avère dangereux voire mortel à cause du risque d'asphyxie ou d'acidose
        Les propriétés du dioxyde de carbone furent étudiées plus en détail dans les années 1750 par le chimiste 
        et physicien écossais Joseph Black. Le dioxyde de carbone est l'un des premiers gaz (avec la vapeur d'eau) 
        à avoir été décrit comme étant une substance distincte de l'air."""
}
schema = _w.Schema()
schema.set_details(**details)

# %%
schema
# Out:
# Schema: `carbon_dioxide_emissions_and_stocks`

# %%
fields = [
    {
        "name": "Country Name",
        "title": "Country Name",
        "type": "string",
        "description": "Official country names.",
        "constraints": {
            "required": True
        }
    },
    {
        "name": "HDI Category",
        "title": "HDI Category",
        "type": "string",
        "description": "Human Development Index Category derived from the HDI Rank.",
    },
    {
        "name": "Indicator Name",
        "title": "Indicator Name",
        "type": "string",
        "description": "Indicator described in the data series.",
    },
    {
        "name": "Reference",
        "title": "Reference",
        "type": "string",
        "description": "Reference to data source.",
    },
    {
        "name": "Values",
        "title": "Values",
        "type": "number",
        "description": "Value for the Year and Indicator Name.",
        "constraints": {
            "required": True
        }
    },
]

# %%
for field in fields:
    schema.set_field(**field)

# %%
schema.default_field_types
# Out:
# ['string',
#  'number',
#  'integer',
#  'boolean',
#  'object',
#  'array',
#  'date',
#  'datetime',
#  'year']

# %%
schema.field("country_name")
# Out:
# {'name': 'country_name',
#  'type': 'string',
#  'constraints': {'required': True},
#  'title': 'Country Name',
#  'description': 'Official country names.'}

# %%
# Enregistrons notre schéma dans un répertoire spécifique

directory = "C:/Users/HP 840 G2/Desktop/DCDJ/Cours_Boyera/Exercice_Leçon_2_2"

# %%
# Spécification d'un nom de fichier facultatif
filename = "Table_24-schema"

# %%
# Verification de l'existence du fichier
schema.save(directory, filename=filename, overwrite=True)
# Out:
# True

# %%
schema.all_field_names
# Out:
# ['country_name', 'hdi_category', 'indicator_name', 'reference', 'values']

# %% [markdown]
# ### 2) Morph et méthode pour transformer les données sources

# %%
# Les importations et paramètres suivants vous permettent d'obtenir un large éventail de résultats pour vos tableaux

from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))

import numpy as np
import whyqd as _w

SCHEMA_SOURCE = "C:/Users/HP 840 G2/Desktop/DCDJ/Cours_Boyera/Exercice_Leçon_2_2Table_24-schema.json"
DIRECTORY = "C:/Users/HP 840 G2/Desktop/DCDJ/Cours_Boyera/Exercice_Leçon_2_2/"
INPUT_DATA = [
    "HDR 2007-2008 Table 24.xlsx"
]
method = _w.Method(SCHEMA_SOURCE, directory=DIRECTORY, input_data=INPUT_DATA)
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
print(method.print_input_data())
# Out:
# Data id: 33e7fdb1-4eff-4934-9004-b43f400591d4
# Original source: HDR 2007-2008 Table 24.xlsx
#
# ====  ======================================  ============  ============================================  ============  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#   ..  Unnamed: 0                                Unnamed: 1  Unnamed: 2                                      Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9    Unnamed: 10    Unnamed: 11    Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15    Unnamed: 16    Unnamed: 17    Unnamed: 18    Unnamed: 19    Unnamed: 20    Unnamed: 21    Unnamed: 22    Unnamed: 23    Unnamed: 24    Unnamed: 25    Unnamed: 26    Unnamed: 27
# ====  ======================================  ============  ============================================  ============  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#    0  nan                                              nan  …while preserving it for future generations…           nan           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    1  24 Carbon dioxide emissions and stocks           nan  nan                                                    nan           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    2  nan                                              nan  nan                                                    nan           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
# ====  ======================================  ============  ============================================  ============  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============

# %%
method.status
# Out:
# 'Ready to Merge'

# %%
method.default_morph_types
# Out:
# ['CATEGORISE', 'DEBLANK', 'DEDUPE', 'DELETE', 'MELT', 'REBASE', 'RENAME']

# %%
_id = method.input_data[0]["id"]
df = method.input_dataframe(_id)
df.head()
# Out:
#                                Unnamed: 0 Unnamed: 1  \
# 0                                     NaN        NaN
# 1  24 Carbon dioxide emissions and stocks        NaN
# 2                                     NaN        NaN
# 3                                     NaN        NaN
# 4                                     NaN        NaN
#
#                                      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  …while preserving it for future generations…        NaN        NaN
# 1                                           NaN        NaN        NaN
# 2                                           NaN        NaN        NaN
# 3                     Carbon dioxide emissionsa        NaN        NaN
# 4                                         Total        NaN        NaN
#
#   Unnamed: 5     Unnamed: 6 Unnamed: 7               Unnamed: 8 Unnamed: 9  \
# 0        NaN            NaN        NaN                      NaN        NaN
# 1        NaN            NaN        NaN                      NaN        NaN
# 2        NaN            NaN        NaN                      NaN        NaN
# 3        NaN            NaN        NaN                      NaN        NaN
# 4        NaN  Annual change        NaN  Share of \nworld totalb        NaN
#
#    ... Unnamed: 18 Unnamed: 19  \
# 0  ...         NaN         NaN
# 1  ...         NaN         NaN
# 2  ...         NaN         NaN
# 3  ...         NaN         NaN
# 4  ...         NaN         NaN
#
#                                          Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                                NaN         NaN         NaN
# 4  Carbon intensity \nof growth\nCO2 emissions \n...         NaN         NaN
#
#   Unnamed: 23                                    Unnamed: 24 Unnamed: 25  \
# 0         NaN                                            NaN         NaN
# 1         NaN                                            NaN         NaN
# 2         NaN                                            NaN         NaN
# 3         NaN                                            NaN         NaN
# 4         NaN  Carbon dioxide emissions from forest biomassc         NaN
#
#                         Unnamed: 26 Unnamed: 27
# 0                               NaN         NaN
# 1                               NaN         NaN
# 2                               NaN         NaN
# 3                               NaN         NaN
# 4  Carbon stocks in forest biomassd         NaN
#
# [5 rows x 28 columns]

# %%
df.head(10)
# Out:
#                                Unnamed: 0 Unnamed: 1  \
# 0                                     NaN        NaN
# 1  24 Carbon dioxide emissions and stocks        NaN
# 2                                     NaN        NaN
# 3                                     NaN        NaN
# 4                                     NaN        NaN
# 5                                     NaN        NaN
# 6                                HDI rank        NaN
# 7                  HIGH HUMAN DEVELOPMENT        NaN
# 8                                       1    Iceland
# 9                                       2     Norway
#
#                                      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  …while preserving it for future generations…        NaN        NaN
# 1                                           NaN        NaN        NaN
# 2                                           NaN        NaN        NaN
# 3                     Carbon dioxide emissionsa        NaN        NaN
# 4                                         Total        NaN        NaN
# 5                                      (Mt CO2)        NaN        NaN
# 6                                          1990        NaN       2004
# 7                                                      NaN        NaN
# 8                                           2.0        NaN        2.2
# 9                                          33.2        NaN       87.5
#
#   Unnamed: 5     Unnamed: 6 Unnamed: 7               Unnamed: 8 Unnamed: 9  \
# 0        NaN            NaN        NaN                      NaN        NaN
# 1        NaN            NaN        NaN                      NaN        NaN
# 2        NaN            NaN        NaN                      NaN        NaN
# 3        NaN            NaN        NaN                      NaN        NaN
# 4        NaN  Annual change        NaN  Share of \nworld totalb        NaN
# 5        NaN            (%)        NaN                    \n(%)        NaN
# 6        NaN      1990-2004        NaN                     1990        NaN
# 7        NaN            NaN        NaN                      NaN        NaN
# 8        NaN            0.7        NaN                      (.)        NaN
# 9        NaN           11.7        NaN                      0.1        NaN
#
#    ... Unnamed: 18 Unnamed: 19  \
# 0  ...         NaN         NaN
# 1  ...         NaN         NaN
# 2  ...         NaN         NaN
# 3  ...         NaN         NaN
# 4  ...         NaN         NaN
# 5  ...         NaN         NaN
# 6  ...        2004         NaN
# 7  ...         NaN         NaN
# 8  ...        0.64         NaN
# 9  ...        3.17         NaN
#
#                                          Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                                NaN         NaN         NaN
# 4  Carbon intensity \nof growth\nCO2 emissions \n...         NaN         NaN
# 5              (kt of CO2 per million\n2000 PPP US$)         NaN         NaN
# 6                                               1990         NaN        2004
# 7                                                NaN         NaN         NaN
# 8                                               0.32         NaN        0.24
# 9                                               0.31         NaN        0.53
#
#   Unnamed: 23                                    Unnamed: 24 Unnamed: 25  \
# 0         NaN                                            NaN         NaN
# 1         NaN                                            NaN         NaN
# 2         NaN                                            NaN         NaN
# 3         NaN                                            NaN         NaN
# 4         NaN  Carbon dioxide emissions from forest biomassc         NaN
# 5         NaN                                (Mt CO2 / year)         NaN
# 6         NaN                                      1990-2005         NaN
# 7         NaN                                            NaN         NaN
# 8         NaN                                           -0.1         NaN
# 9         NaN                                          -15.6         NaN
#
#                         Unnamed: 26 Unnamed: 27
# 0                               NaN         NaN
# 1                               NaN         NaN
# 2                               NaN         NaN
# 3                               NaN         NaN
# 4  Carbon stocks in forest biomassd         NaN
# 5                       (Mt Carbon)         NaN
# 6                              2005         NaN
# 7                               NaN         NaN
# 8                               1.5         NaN
# 9                             344.0         NaN
#
# [10 rows x 28 columns]

# %%
method.add_input_data_morph(_id, ["REBASE", 7])

# %%
rows = [int(i) for i in np.arange(188, df.index[-1]+1)]
method.add_input_data_morph(_id, ["DELETE", rows])

# %%
df.tail()
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 214                                              NOTES        NaN        NaN
# 215                                                NaN        NaN        NaN
# 216  a. Refers to carbon dioxide emissions stemming...        NaN        NaN
# 217                                                NaN        NaN        NaN
# 218  SOURCES\nColumns 1, 2 and 4—7: calculated base...        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 214        NaN        NaN        NaN        NaN        NaN        NaN
# 215        NaN        NaN        NaN        NaN        NaN        NaN
# 216        NaN        NaN        NaN        NaN        NaN        NaN
# 217        NaN        NaN        NaN        NaN        NaN        NaN
# 218        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 9  ... Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 214        NaN  ...         NaN         NaN         NaN         NaN
# 215        NaN  ...         NaN         NaN         NaN         NaN
# 216        NaN  ...         NaN         NaN         NaN         NaN
# 217        NaN  ...         NaN         NaN         NaN         NaN
# 218        NaN  ...         NaN         NaN         NaN         NaN
#
#     Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27
# 214         NaN         NaN         NaN         NaN         NaN         NaN
# 215         NaN         NaN         NaN         NaN         NaN         NaN
# 216         NaN         NaN         NaN         NaN         NaN         NaN
# 217         NaN         NaN         NaN         NaN         NaN         NaN
# 218         NaN         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 28 columns]

# %%
df = method.input_dataframe(_id)
df.tail(20)
# Out:
#     HIGH HUMAN DEVELOPMENT                                 NaN        NaN  \
# 167                    158                             Nigeria  45.3  NaN
# 168                    159       Tanzania (United Republic of)   2.3  NaN
# 169                    160                              Guinea   1.0  NaN
# 170                    161                              Rwanda   0.5  NaN
# 171                    162                              Angola   4.6  NaN
# 172                    163                               Benin   0.7  NaN
# 173                    164                              Malawi   0.6  NaN
# 174                    165                              Zambia   2.4  NaN
# 175                    166                       Côte d'Ivoire   5.4  NaN
# 176                    167                             Burundi   0.2  NaN
# 177                    168  Congo (Democratic Republic of the)   4.0  NaN
# 178                    169                            Ethiopia   3.0  NaN
# 179                    170                                Chad   0.1  NaN
# 180                    171            Central African Republic   0.2  NaN
# 181                    172                          Mozambique   1.0  NaN
# 182                    173                                Mali   0.4  NaN
# 183                    174                               Niger   1.0  NaN
# 184                    175                       Guinea-Bissau   0.2  NaN
# 185                    176                        Burkina Faso   1.0  NaN
# 186                    177                        Sierra Leone   0.3  NaN
#
#        NaN  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN   NaN   NaN   NaN  \
# 167  114.0  NaN  10.8  NaN  0.2  NaN  ...  0.5  NaN  0.9  0.64  1.15  0.59
# 168    4.3  NaN   6.2  NaN  (.)  NaN  ...  0.1  NaN  0.1  0.24  0.23  0.17
# 169    1.3  NaN   2.3  NaN  (.)  NaN  ...  0.2  NaN  0.1    ..    ..  0.09
# 170    0.6  NaN   0.6  NaN  (.)  NaN  ...  0.1  NaN  0.1    ..    ..  0.07
# 171    7.9  NaN   5.0  NaN  (.)  NaN  ...  0.5  NaN  0.7  0.74  0.83  0.25
# 172    2.4  NaN  16.7  NaN  (.)  NaN  ...  0.1  NaN  0.3  0.43  0.96  0.16
# 173    1.0  NaN   5.3  NaN  (.)  NaN  ...  0.1  NaN  0.1    ..    ..  0.13
# 174    2.3  NaN  -0.5  NaN  (.)  NaN  ...  0.3  NaN  0.2  0.45  0.33  0.31
# 175    5.2  NaN  -0.3  NaN  (.)  NaN  ...  0.5  NaN  0.3  1.22  0.74  0.26
# 176    0.2  NaN   0.9  NaN  (.)  NaN  ...  (.)  NaN  (.)    ..    ..  0.04
# 177    2.1  NaN  -3.4  NaN  (.)  NaN  ...  0.1  NaN  (.)  0.33  0.13  0.07
# 178    8.0  NaN  12.1  NaN  (.)  NaN  ...  0.1  NaN  0.1  0.20  0.38  0.07
# 179    0.1  NaN  -0.9  NaN  (.)  NaN  ...  (.)  NaN  0.0    ..    ..  0.03
# 180    0.3  NaN   2.0  NaN  (.)  NaN  ...  0.1  NaN  0.1    ..    ..  0.05
# 181    2.2  NaN   8.4  NaN  (.)  NaN  ...  0.1  NaN  0.1  0.14  0.25  0.12
# 182    0.6  NaN   2.4  NaN  (.)  NaN  ...  (.)  NaN  (.)    ..    ..  0.07
# 183    1.2  NaN   1.1  NaN  (.)  NaN  ...  0.1  NaN  0.1    ..    ..  0.16
# 184    0.3  NaN   2.1  NaN  (.)  NaN  ...  0.2  NaN  0.2    ..    ..  0.21
# 185    1.1  NaN   0.7  NaN  (.)  NaN  ...  0.1  NaN  0.1    ..    ..  0.13
# 186    1.0  NaN  14.1  NaN  (.)  NaN  ...  0.1  NaN  0.2    ..    ..  0.10
#
#      NaN   NaN    NaN       NaN
# 167  NaN  0.92  181.6   1,401.5
# 168  NaN  0.18  167.3   2,254.0
# 169  NaN  0.07   15.9     636.0
# 170  NaN  0.06   -2.1      44.1
# 171  NaN  0.29   37.6   4,829.3
# 172  NaN  0.29     ..        ..
# 173  NaN  0.14    5.6     161.0
# 174  NaN  0.23   44.4   1,156.1
# 175  NaN  0.20   -9.0   1,864.0
# 176  NaN  0.05     ..        ..
# 177  NaN  0.06  293.1  23,173.0
# 178  NaN  0.13   13.4     252.0
# 179  NaN  0.01    5.6     236.0
# 180  NaN  0.06   13.7   2,801.0
# 181  NaN  0.11    5.7     606.3
# 182  NaN  0.05    7.1     241.9
# 183  NaN  0.13    1.7      12.5
# 184  NaN  0.24    0.5      61.0
# 185  NaN  0.08   19.1     298.0
# 186  NaN  0.27     ..        ..
#
# [20 rows x 21 columns]

# %%
columns = [
    "HDI rank",
    "Country",
    "Total (Mt CO2)_1990",
    "Reference 1",
    "Total (Mt CO2)_2004",
    "Reference 2",
    "Annual change (%)_1990-2004",
    "Reference 3",
    "Share of world total (%)_1990",
    "Reference 4",
    "Share of world total (%)_2004",
    "Per capita (t CO2)_1990",
    "Reference 5",
    "Per capita (t CO2)_2004",
    "Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_1990",
    "Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_2004",
    "Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_1990",
    "Reference 6",
    "Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_2004",
    "Carbon dioxide emissions from forest biomass (Mt CO2 / year)_1990-2005",
    "Carbon stocks in forest biomass (Mt Carbon)_2005"
]

# %%
method.add_input_data_morph(_id, ["RENAME", columns])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#    HDI rank    Country Total (Mt CO2)_1990 Reference 1 Total (Mt CO2)_2004  \
# 8         1    Iceland                 2.0         NaN                 2.2
# 9         2     Norway                33.2         NaN                87.5
# 10        3  Australia               278.5         NaN               326.6
# 11        4     Canada               415.8         NaN               639.0
# 12        5    Ireland                30.6         NaN                42.3
#
#    Reference 2 Annual change (%)_1990-2004 Reference 3  \
# 8          NaN                         0.7         NaN
# 9          NaN                        11.7         NaN
# 10         NaN                         1.2         NaN
# 11         NaN                         3.8         NaN
# 12         NaN                         2.7         NaN
#
#    Share of world total (%)_1990 Reference 4  ... Per capita (t CO2)_1990  \
# 8                            (.)         NaN  ...                     7.9
# 9                            0.1         NaN  ...                     7.8
# 10                           1.2         NaN  ...                    16.3
# 11                           1.8         NaN  ...                    15.0
# 12                           0.1         NaN  ...                     8.8
#
#    Reference 5 Per capita (t CO2)_2004  \
# 8          NaN                     7.6
# 9          NaN                    19.1
# 10         NaN                    16.2
# 11         NaN                    20.0
# 12         NaN                    10.5
#
#    Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_1990  \
# 8                                                0.93
# 9                                                1.54
# 10                                               3.18
# 11                                               1.99
# 12                                               2.94
#
#    Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_2004  \
# 8                                                0.64
# 9                                                3.17
# 10                                               2.82
# 11                                               2.38
# 12                                               2.78
#
#    Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_1990  \
# 8                                                0.32
# 9                                                0.31
# 10                                               0.81
# 11                                               0.66
# 12                                               0.55
#
#    Reference 6  \
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
#
#    Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_2004  \
# 8                                                0.24
# 9                                                0.53
# 10                                               0.58
# 11                                               0.69
# 12                                               0.31
#
#    Carbon dioxide emissions from forest biomass (Mt CO2 / year)_1990-2005  \
# 8                                                -0.1
# 9                                               -15.6
# 10                                                 ..
# 11                                                 ..
# 12                                               -1.0
#
#    Carbon stocks in forest biomass (Mt Carbon)_2005
# 8                                               1.5
# 9                                             344.0
# 10                                          8,339.0
# 11                                               ..
# 12                                             19.8
#
# [5 rows x 21 columns]

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
rows = df[df["HDI rank"].isin(hdi_categories)].index

# %%
rows
# Out:
# Int64Index([78, 164], dtype='int64')

# %%
# df.fillna(method='ffill')

# %%
# df.fillna(method='ffill', inplace=True)

# %%
method.default_morph_settings("CATEGORISE")
# Out:
# {'name': 'CATEGORISE',
#  'title': 'Categorise',
#  'type': 'morph',
#  'description': 'Convert row-level categories into column categorisations.',
#  'structure': ['rows', 'column_names']}

# %%
method.default_morph_settings("DEBLANK")
# Out:
# {'name': 'DEBLANK',
#  'title': 'De-blank',
#  'type': 'morph',
#  'description': 'Remove all blank columns and rows from a DataFrame.',
#  'structure': []}

# %%
method.add_input_data_morph(_id, ["CATEGORISE", list(rows), "HDI category"])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#    HDI rank    Country Total (Mt CO2)_1990 Reference 1 Total (Mt CO2)_2004  \
# 8         1    Iceland                 2.0         NaN                 2.2
# 9         2     Norway                33.2         NaN                87.5
# 10        3  Australia               278.5         NaN               326.6
# 11        4     Canada               415.8         NaN               639.0
# 12        5    Ireland                30.6         NaN                42.3
#
#    Reference 2 Annual change (%)_1990-2004 Reference 3  \
# 8          NaN                         0.7         NaN
# 9          NaN                        11.7         NaN
# 10         NaN                         1.2         NaN
# 11         NaN                         3.8         NaN
# 12         NaN                         2.7         NaN
#
#    Share of world total (%)_1990 Reference 4  ... Reference 5  \
# 8                            (.)         NaN  ...         NaN
# 9                            0.1         NaN  ...         NaN
# 10                           1.2         NaN  ...         NaN
# 11                           1.8         NaN  ...         NaN
# 12                           0.1         NaN  ...         NaN
#
#    Per capita (t CO2)_2004  \
# 8                      7.6
# 9                     19.1
# 10                    16.2
# 11                    20.0
# 12                    10.5
#
#    Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_1990  \
# 8                                                0.93
# 9                                                1.54
# 10                                               3.18
# 11                                               1.99
# 12                                               2.94
#
#    Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_2004  \
# 8                                                0.64
# 9                                                3.17
# 10                                               2.82
# 11                                               2.38
# 12                                               2.78
#
#    Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_1990  \
# 8                                                0.32
# 9                                                0.31
# 10                                               0.81
# 11                                               0.66
# 12                                               0.55
#
#    Reference 6  \
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
#
#    Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_2004  \
# 8                                                0.24
# 9                                                0.53
# 10                                               0.58
# 11                                               0.69
# 12                                               0.31
#
#    Carbon dioxide emissions from forest biomass (Mt CO2 / year)_1990-2005  \
# 8                                                -0.1
# 9                                               -15.6
# 10                                                 ..
# 11                                                 ..
# 12                                               -1.0
#
#    Carbon stocks in forest biomass (Mt Carbon)_2005 HDI category
# 8                                               1.5          NaN
# 9                                             344.0          NaN
# 10                                          8,339.0          NaN
# 11                                               ..          NaN
# 12                                             19.8          NaN
#
# [5 rows x 22 columns]

# %%
# Regroupons les indicateurs suivant la methode "melt"
columns = [
    "HDI rank",
    "Total (Mt CO2)_1990",
    "Total (Mt CO2)_2004",
    "Annual change (%)_1990-2004",
    "Share of world total (%)_1990",
    "Share of world total (%)_2004",
    "Per capita (t CO2)_1990",
    "Per capita (t CO2)_2004",
    "Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_1990",
    "Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_2004",
    "Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_1990",
    "Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_2004",
    "Carbon dioxide emissions from forest biomass (Mt CO2 / year)_1990-2005",
    "Carbon stocks in forest biomass (Mt Carbon)_2005"
]
method.add_input_data_morph(_id, ["MELT", columns, ["Indicator Name", "Indicator Value"]])

# %%
# Regroupons les réferences suivant la methode "melt"
columns = [
    "Reference 1",
    "Reference 2",
    "Reference 3",
    "Reference 4",
    "Reference 5",
    "Reference 6",
]
method.add_input_data_morph(_id, ["MELT", columns, ["Reference Name", "Reference"]])

# %%
method.add_input_data_morph(_id, ["DEBLANK"])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#   Indicator Name    Country HDI category Indicator Value Reference Name  \
# 0       HDI rank    Iceland          NaN               1    Reference 1
# 1       HDI rank     Norway          NaN               2    Reference 1
# 2       HDI rank  Australia          NaN               3    Reference 1
# 3       HDI rank     Canada          NaN               4    Reference 1
# 4       HDI rank    Ireland          NaN               5    Reference 1
#
#   Reference
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df["HDI category"].fillna(method='ffill', inplace=True)

# df["HDI category"].fillna(method='backfill', inplace=True)

df.head(100)
# Out:
#    Indicator Name     Country              HDI category Indicator Value  \
# 0        HDI rank     Iceland                       NaN               1
# 1        HDI rank      Norway                       NaN               2
# 2        HDI rank   Australia                       NaN               3
# 3        HDI rank      Canada                       NaN               4
# 4        HDI rank     Ireland                       NaN               5
# ..            ...         ...                       ...             ...
# 95       HDI rank     Georgia  MEDIUM HUMAN DEVELOPMENT              96
# 96       HDI rank      Guyana  MEDIUM HUMAN DEVELOPMENT              97
# 97       HDI rank  Azerbaijan  MEDIUM HUMAN DEVELOPMENT              98
# 98       HDI rank   Sri Lanka  MEDIUM HUMAN DEVELOPMENT              99
# 99       HDI rank    Maldives  MEDIUM HUMAN DEVELOPMENT             100
#
#    Reference Name Reference
# 0     Reference 1       NaN
# 1     Reference 1       NaN
# 2     Reference 1       NaN
# 3     Reference 1       NaN
# 4     Reference 1       NaN
# ..            ...       ...
# 95    Reference 1         i
# 96    Reference 1       NaN
# 97    Reference 1         i
# 98    Reference 1       NaN
# 99    Reference 1       NaN
#
# [100 rows x 6 columns]

# %%
print(method.help("structure"))
# Out:
# `structure` is the core of the wrangling process and is the process where you define the actions
# which must be performed to restructure your working data.
#
# Create a list of methods of the form:
#
# 	{
# 		"schema_field1": ["action", "column_name1", ["action", "column_name2"]],
# 		"schema_field2": ["action", "column_name1", "modifier", ["action", "column_name2"]],
# 	}
#
# The format for defining a `structure` is as follows::
#
# 	[action, column_name, [action, column_name]]
#
# e.g.::
#
# 	["CATEGORISE", "+", ["ORDER", "column_1", "column_2"]]
#
# This permits the creation of quite expressive wrangling structures from simple building
# blocks.
#
# The schema for this method consists of the following terms:
#
# ['country_name', 'hdi_category', 'indicator_name', 'reference', 'values']
#
# The actions:
#
# ['CALCULATE', 'CATEGORISE', 'JOIN', 'NEW', 'ORDER', 'ORDER_NEW', 'ORDER_OLD', 'RENAME']
#
# The columns from your working data:
#
# []
#
#
# Current method status: `Ready to Merge`

# %%
# %time method.merge(overwrite_working=True)
# Out:
# Wall time: 5.59 s

# %%
print(method.help("structure"))
# Out:
# `structure` is the core of the wrangling process and is the process where you define the actions
# which must be performed to restructure your working data.
#
# Create a list of methods of the form:
#
# 	{
# 		"schema_field1": ["action", "column_name1", ["action", "column_name2"]],
# 		"schema_field2": ["action", "column_name1", "modifier", ["action", "column_name2"]],
# 	}
#
# The format for defining a `structure` is as follows::
#
# 	[action, column_name, [action, column_name]]
#
# e.g.::
#
# 	["CATEGORISE", "+", ["ORDER", "column_1", "column_2"]]
#
# This permits the creation of quite expressive wrangling structures from simple building
# blocks.
#
# The schema for this method consists of the following terms:
#
# ['country_name', 'hdi_category', 'indicator_name', 'reference', 'values']
#
# The actions:
#
# ['CALCULATE', 'CATEGORISE', 'JOIN', 'NEW', 'ORDER', 'ORDER_NEW', 'ORDER_OLD', 'RENAME']
#
# The columns from your working data:
#
# ['Indicator Name', 'Country', 'HDI category', 'Indicator Value', 'Reference Name', 'Reference']
#
#
# Data id: working_b1e925c2-f79d-465d-82dd-4d5353dd7d95
# Original source: method.input_data
#
# ====  ================  =========  ==============  =================  ================  ===========
#   ..  Indicator Name    Country      HDI category    Indicator Value  Reference Name      Reference
# ====  ================  =========  ==============  =================  ================  ===========
#    0  HDI rank          Iceland               nan                  1  Reference 1               nan
#    1  HDI rank          Norway                nan                  2  Reference 1               nan
#    2  HDI rank          Australia             nan                  3  Reference 1               nan
# ====  ================  =========  ==============  =================  ================  ===========
#
#
# Current method status: `Ready to Structure`

# %%
print(method.help())
# Out:
# **whyqd** provides data wrangling simplicity, complete audit transparency, and at speed.
#
# To get help, type:
#
# 	>>> method.help(option)
#
# Where `option` can be any of:
#
# 	status
# 	merge
# 	structure
# 	category
# 	filter
# 	transform
#
# `status` will return the current method status, and your mostly likely next steps. The other options
# will return methodology, and output of that option's result (if appropriate). The `error` will
# present an error trace and attempt to guide you to fix the process problem.
#
# Current method status: `Ready to Structure`

# %%
df.dtypes
# Out:
# Indicator Name     object
# Country            object
# HDI category       object
# Indicator Value    object
# Reference Name     object
# Reference          object
# dtype: object

# %%
structure = {
    "country_name": ["RENAME", "Country"],
    "hdi_category": ["RENAME", "HDI category"],
    "indicator_name": ["RENAME", "Indicator Name"],
    "values": ["RENAME", "Indicator Value"],
}

# %%
method.set_structure(**structure)

# %%
method.transform(overwrite_output=True)
FILENAME = "Table_24"
method.save(directory, filename=FILENAME, overwrite=True)

# %%
method.input_data_morphs(_id)
# Out:
# [{'f84f8cac-352e-4923-aa3d-2c162ff06ac3': ['DEBLANK']},
#  {'fff4860b-b957-4ce7-af28-443e76a87fdd': ['DEDUPE']},
#  {'420f2029-303e-4be3-b539-353c33dc88e3': ['REBASE', [7]]},
#  {'2d06b89e-73bb-4f91-be5a-31e38592b771': ['DELETE',
#    [188,
#     189,
#     190,
#     191,
#     192,
#     193,
#     194,
#     195,
#     196,
#     197,
#     198,
#     199,
#     200,
#     201,
#     202,
#     203,
#     204,
#     205,
#     206,
#     207,
#     208,
#     209,
#     210,
#     211,
#     212,
#     213,
#     214,
#     215,
#     216,
#     217,
#     218]]},
#  {'c0a09b42-0c90-499a-a1c0-08b29ce1a9b4': ['RENAME',
#    ['HDI rank',
#     'Country',
#     'Total (Mt CO2)_1990',
#     'Reference 1',
#     'Total (Mt CO2)_2004',
#     'Reference 2',
#     'Annual change (%)_1990-2004',
#     'Reference 3',
#     'Share of world total (%)_1990',
#     'Reference 4',
#     'Share of world total (%)_2004',
#     'Per capita (t CO2)_1990',
#     'Reference 5',
#     'Per capita (t CO2)_2004',
#     'Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_1990',
#     'Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_2004',
#     'Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_1990',
#     'Reference 6',
#     'Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_2004',
#     'Carbon dioxide emissions from forest biomass (Mt CO2 / year)_1990-2005',
#     'Carbon stocks in forest biomass (Mt Carbon)_2005']]},
#  {'933fd9a0-21c2-49da-a817-86ed9c3c14f3': ['CATEGORISE',
#    [78, 164],
#    ['HDI category']]},
#  {'e603027b-9d3f-4e8e-857d-03f05ad4a91d': ['MELT',
#    [['Reference 1',
#      'Country',
#      'Reference 2',
#      'Reference 5',
#      'Reference 6',
#      'HDI category',
#      'Reference 3',
#      'Reference 4'],
#     ['HDI rank',
#      'Total (Mt CO2)_1990',
#      'Total (Mt CO2)_2004',
#      'Annual change (%)_1990-2004',
#      'Share of world total (%)_1990',
#      'Share of world total (%)_2004',
#      'Per capita (t CO2)_1990',
#      'Per capita (t CO2)_2004',
#      'Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_1990',
#      'Carbon intensity of energy (kt of CO2 per kt of oil equivalent)_2004',
#      'Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_1990',
#      'Carbon intensity of growth (kt of CO2 per million 2000 PPP US$)_2004',
#      'Carbon dioxide emissions from forest biomass (Mt CO2 / year)_1990-2005',
#      'Carbon stocks in forest biomass (Mt Carbon)_2005']],
#    ['Indicator Name', 'Indicator Value']]},
#  {'13f58f45-96b8-44c5-9588-f2d23639b6f2': ['MELT',
#    [['Indicator Name', 'Country', 'HDI category', 'Indicator Value'],
#     ['Reference 1',
#      'Reference 2',
#      'Reference 3',
#      'Reference 4',
#      'Reference 5',
#      'Reference 6']],
#    ['Reference Name', 'Reference']]},
#  {'f3162019-3cd7-47b6-98f2-a917a19299fc': ['DEBLANK']}]

# %%
# %time method.validates
# Out:
# Wall time: 4.58 s
# True

# %% [markdown]
# ### 3) Validation et manipulation via l'utilisation de PandasSchema pour examiner nos données de sortie

# %%
import pandas as pd
import numpy as np

source = "C:/Users/HP 840 G2/Desktop/DCDJ/Cours_Boyera/Exercice_Leçon_2_2/output_29b8dbae-9b1d-4eb7-943c-0c354ba4fd85.csv"

df = pd.read_csv(source)
df.head()
# Out:
#    reference country_name hdi_category indicator_name values
# 0        NaN      Iceland          NaN       HDI rank      1
# 1        NaN       Norway          NaN       HDI rank      2
# 2        NaN    Australia          NaN       HDI rank      3
# 3        NaN       Canada          NaN       HDI rank      4
# 4        NaN      Ireland          NaN       HDI rank      5

# %%
from pandas_schema import Column, Schema
from pandas_schema.validation import LeadingWhitespaceValidation, TrailingWhitespaceValidation, IsDtypeValidation, InListValidation

# Nous ne testerons que ces colonnes
columns = ["country_name", "hdi_category", "values"]
# Et ces catégories
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]

# %%
schema = Schema([
    Column("country_name", [LeadingWhitespaceValidation(), TrailingWhitespaceValidation()]),
    Column("hdi_category", [InListValidation(hdi_categories)]),
    Column("values", [IsDtypeValidation(np.dtype(float)), IsDtypeValidation(np.dtype(int))])
])

# %%
errors = schema.validate(df[columns])

print(F"Nombre d'erreurs :  {len(errors)}")
# Juste les 10 premiers
for error in errors[:10]:
    print(error)
# Out:
# Nombre d'erreurs :  1094
# The column values has a dtype of object which is not a subclass of the required type float64
# The column values has a dtype of object which is not a subclass of the required type int32
# {row: 0, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 1, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 2, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 3, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 4, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 5, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 6, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 7, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)

# %% [markdown]
# ### 4) Présentons notre citation et dressons la liste des fichiers, métadonnées et informations que nous avons l'intention de publier dans le cadre de cet exercice.

# %%
for l in method.citation.split(","):
    print(l)
# Out:
# 2020-05-25
#  Carbon dioxide emissions and stocks in the world
#  21cadea18a1affce2ebdac9893b43f4f1b02e386575b45f073c71eebbe996d073bbb7a549b13bed5aca22277979bb8e8a0108fc802735df7073f9fec70cfe2b9
#  [input sources: HDR 2007-2008 Table 24.xlsx
#  862508122dcac562b598d1d9f178384b8ccd627d24573491e0f597a2eacae4a41ff7f5e909a31a9a06ac3a58017a9c07b1f2d62fdf7b17b8029fdf06baf268bf]
